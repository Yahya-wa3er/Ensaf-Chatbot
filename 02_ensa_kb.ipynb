# %%
import json

ensa_data = [
  {
    "id": "fi001",
    "category": "filieres",
    "question": "Quelles sont les filières de formation initiale disponibles à l'ENSA Fès ?",
    "answer": "L'ENSA Fès propose 11 filières de cycle ingénieur en formation initiale : Génie des Systèmes Communicants et Sécurité Informatique, Génie du Développement Numérique et Cybersécurité, Génie Énergétique et Systèmes Intelligents, Génie Industriel, Génie Informatique, Génie Mécanique, Génie Mécatronique, Ingénierie des Systèmes Embarqués et Intelligence Artificielle, Ingénierie en Science de Données et Intelligence Artificielle, Ingénierie Informatique Intelligence Artificielle et Confiance Numérique, et Ingénierie Logicielle et Intelligence Artificielle. Ces filières sont précédées d'un Cycle Préparatoire de 2 ans.",
    "context": "L'ENSA Fès offre une large gamme de filières d'ingénierie couvrant l'informatique, l'électronique, la mécanique, l'énergie et l'intelligence artificielle."
  },
  {
    "id": "fi002",
    "category": "filieres",
    "question": "Combien d'années dure la formation à l'ENSA Fès ?",
    "answer": "La formation à l'ENSA Fès dure 5 ans au total : 2 ans de Cycle Préparatoire Intégré (CPI) suivis de 3 ans de cycle ingénieur. Le cycle préparatoire couvre les fondamentaux scientifiques (mathématiques, physique, informatique, langues), tandis que le cycle ingénieur est centré sur la spécialité choisie.",
    "context": "L'ENSA Fès suit le modèle national des écoles nationales des sciences appliquées avec une formation en 5 ans."
  },
  {
    "id": "fi003",
    "category": "filieres",
    "question": "Quels sont les départements de l'ENSA Fès ?",
    "answer": "L'ENSA Fès est organisée en 6 départements : Génie Industriel, Génie Électrique et Informatique, Génie des Systèmes Intelligents, Mathématiques Appliquées, Intelligence Économique Langues et Soft-Skills, et Sciences des Données et Systèmes Communicants. Chaque département supervise plusieurs filières et dispose d'un chef de département et de coordinateurs de filières.",
    "context": "Les départements de l'ENSA Fès regroupent les enseignants-chercheurs par domaine de spécialité et assurent la coordination pédagogique des filières."
  },
  {
    "id": "fi004",
    "category": "filieres",
    "question": "Qu'est-ce que la filière Génie Informatique à l'ENSA Fès ?",
    "answer": "La filière Génie Informatique forme des ingénieurs polyvalents en développement logiciel, réseaux, bases de données et intelligence artificielle. Le programme couvre la programmation orientée objet, le développement web full stack, les réseaux avancés et la cybersécurité, les bases de données avancées, l'IA (machine learning et deep learning), le big data, le développement mobile, les systèmes embarqués, et les architectures logicielles avancées. La filière est coordonnée par BOULAALAM ABDELHAK.",
    "context": "La filière GI de l'ENSA Fès est rattachée au département Génie Électrique et Informatique."
  },
  {
    "id": "fi005",
    "category": "filieres",
    "question": "Quels modules sont enseignés en Génie Informatique à l'ENSA Fès ?",
    "answer": "La filière Génie Informatique comprend des modules répartis sur 3 ans de cycle ingénieur. En 1ère année : POO, réseaux fondamentaux, bases de données, systèmes, mathématiques pour l'ingénieur, développement web full stack, modélisation Java. En 2ème année : JEE, Python pour l'IA, probabilités/statistiques, NoSQL, développement mobile, IoT, business intelligence, machine learning et deep learning. En 3ème année : gestion de projet agile, tests logiciels, big data, DevOps, architectures logicielles (SOA, microservices).",
    "context": "Le programme de GI à l'ENSA Fès est structuré en modules semestriels couvrant les domaines techniques et professionnels."
  },
  {
    "id": "fi006",
    "category": "filieres",
    "question": "Qu'est-ce que la filière Génie des Systèmes Communicants et Sécurité Informatique ?",
    "answer": "Cette filière forme des ingénieurs spécialisés en réseaux, systèmes de communication et sécurité informatique. Le programme aborde les fondements des réseaux, la programmation Java et Python, les technologies web, la sécurité des réseaux et systèmes, les techniques de détection des intrusions, la blockchain, les réseaux radio mobiles, les antennes, les micro-ondes et les communications spatiales. Elle est coordonnée par BALBOUL YOUNES et rattachée au département Sciences des Données et Systèmes Communicants.",
    "context": "La filière GSCSI prépare des ingénieurs à la gestion et sécurisation des infrastructures de communication."
  },
  {
    "id": "fi007",
    "category": "filieres",
    "question": "Quels modules sont enseignés en Génie des Systèmes Communicants et Sécurité Informatique ?",
    "answer": "La filière GSCSI couvre en 1ère année : systèmes d'exploitation, réseaux fondamentaux, Java, bases de données, fondements de l'IA. En 2ème année : administration réseau/système, technologies web, API Java, services réseaux et cryptographie, Python et IA, sécurité des réseaux, réseaux d'entreprise, virtualisation et cloud computing. En 3ème année : blockchain, micro-ondes, communications spatiales, forensique et audit de sécurité, systèmes de communication optique, entrepreneuriat.",
    "context": "Chaque module est de 48H et couvre des éléments théoriques et pratiques."
  },
  {
    "id": "fi008",
    "category": "filieres",
    "question": "Qu'est-ce que la filière Génie du Développement Numérique et Cybersécurité ?",
    "answer": "Cette filière forme des ingénieurs experts en développement logiciel sécurisé et en cybersécurité. Elle couvre la programmation C++, Java, Python, le développement web et mobile, la cybersécurité, la cryptographie et blockchain, le ethical hacking, l'analyse des malwares, le cloud computing, la sécurité cloud et IoT, la conteneurisation et DevSecOps, et la gouvernance de la sécurité. Elle est coordonnée par JEGHAL ADIL.",
    "context": "La filière GDNC est rattachée au département Génie Électrique et Informatique."
  },
  {
    "id": "fi009",
    "category": "filieres",
    "question": "Quels modules sont enseignés en Génie du Développement Numérique et Cybersécurité ?",
    "answer": "La filière GDNC propose en 1ère année : POO C++, réseaux fondamentaux, systèmes d'exploitation, bases de données, mathématiques pour la cybersécurité. En 2ème année : administration système avancée, cybersécurité, développement web et mobile, cryptographie et blockchain, systèmes embarqués, réalité virtuelle avec IA. En 3ème année : ethical hacking, intelligence artificielle, attaques et analyse des malwares, cloud computing, architecture logicielle avancée, sécurité cloud et IoT, conteneurisation et DevSecOps, gouvernance de la sécurité.",
    "context": "Chaque module est de 48H et couvre des éléments théoriques et pratiques."
  },
  {
    "id": "fi010",
    "category": "filieres",
    "question": "Qu'est-ce que la filière Génie Énergétique et Systèmes Intelligents ?",
    "answer": "Cette filière forme des ingénieurs spécialisés dans les systèmes énergétiques, les énergies renouvelables et les systèmes intelligents. Le programme comprend la thermodynamique appliquée, les transferts de chaleur, les machines électriques, l'électronique de puissance, l'énergie solaire, éolienne, hydroélectrique, nucléaire et l'hydrogène vert, les systèmes embarqués, le machine learning pour l'énergie, les smart grids, les véhicules intelligents et l'audit énergétique. Elle est coordonnée par HIHI HICHAM.",
    "context": "La filière GESI est rattachée au département Génie Industriel."
  },
  {
    "id": "fi011",
    "category": "filieres",
    "question": "Qu'est-ce que la filière Génie Industriel à l'ENSA Fès ?",
    "answer": "La filière Génie Industriel forme des ingénieurs capables de concevoir, optimiser et gérer des systèmes de production industriels. Elle couvre la robotique, le lean manufacturing, la supply chain, la gestion de production et des stocks, les procédés industriels et l'industrie 4.0, les matériaux innovants, la régulation industrielle, la sureté de fonctionnement, la maintenance industrielle, l'écologie industrielle et l'innovation. Elle est coordonnée par EL KHATTABI SOUAD.",
    "context": "La filière GI est rattachée au département Génie Industriel."
  },
  {
    "id": "fi012",
    "category": "filieres",
    "question": "Qu'est-ce que la filière Génie Mécanique à l'ENSA Fès ?",
    "answer": "La filière Génie Mécanique forme des ingénieurs en conception mécanique, simulation numérique et fabrication. Le programme comprend la résistance des matériaux, la mécanique des fluides, les transferts thermiques, le calcul des structures, la mécatronique, les matériaux innovants, l'intelligence artificielle en mécanique, les éléments finis, l'aérodynamique numérique, la mécanique de rupture et fatigue, et les domaines automobile et aéronautique. Elle est coordonnée par EL HAINI JAMILA.",
    "context": "La filière GM est rattachée au département Génie Industriel."
  },
  {
    "id": "fi013",
    "category": "filieres",
    "question": "Qu'est-ce que la filière Génie Mécatronique à l'ENSA Fès ?",
    "answer": "La filière Génie Mécatronique combine mécanique, électronique, informatique et automatique pour concevoir des systèmes complexes. Elle couvre l'électronique numérique, les microcontrôleurs, la CAO, le traitement du signal, la robotique, les systèmes embarqués, la vision par ordinateur, les machines électriques, la commande moderne, l'IA pour la mécatronique, et les systèmes embarqués automobile et avionique. Elle est coordonnée par SAYYOURI MHAMED.",
    "context": "La filière Mécatronique est rattachée au département Génie Industriel."
  },
  {
    "id": "fi014",
    "category": "filieres",
    "question": "Qu'est-ce que la filière Ingénierie des Systèmes Embarqués et Intelligence Artificielle ?",
    "answer": "Cette filière forme des ingénieurs spécialisés dans la conception de systèmes embarqués intelligents. Le programme couvre les architectures de processeurs embarqués, les systèmes électroniques, l'électronique de puissance, les circuits programmables (FPGA, VHDL), le traitement du signal, le processeur ARM, Linux embarqué, l'IA embarquée de confiance, la vision embarquée, les systèmes temps réels, la cybersécurité des systèmes embarqués et les technologies pour véhicules électriques et autonomes. Elle est coordonnée par ALAMI MARKTANI MALIKA.",
    "context": "La filière ISEAI est rattachée au département Génie des Systèmes Intelligents."
  },
  {
    "id": "fi015",
    "category": "filieres",
    "question": "Qu'est-ce que la filière Ingénierie en Science de Données et Intelligence Artificielle ?",
    "answer": "Cette filière forme des ingénieurs data scientists et experts en IA. Le programme couvre Python pour la data science, le machine learning, le deep learning, le big data, NoSQL, la business intelligence, les systèmes multiagents, la blockchain, le cloud computing, le computer vision, le NLP (traitement du langage naturel), les systèmes de recommandation, l'apprentissage par renforcement, et MLOps. Elle est coordonnée par EL AKKAD NABIL.",
    "context": "La filière ISDAI est rattachée au département Génie Électrique et Informatique."
  },
  {
    "id": "fi016",
    "category": "filieres",
    "question": "Qu'est-ce que la filière Ingénierie Informatique, Intelligence Artificielle et Confiance Numérique ?",
    "answer": "Cette filière forme des ingénieurs alliant développement logiciel, IA et sécurité numérique. Elle couvre Java, Python, les fondements de l'IA, les réseaux et administration système, la cryptographie, le machine learning, le deep learning, le NLP, la sécurité des réseaux, le cloud et DevOps, les techniques de hacking, la blockchain, le big data analytics, les ERP et frameworks web. Elle est coordonnée par BERRADA MOHAMMED.",
    "context": "La filière IIIACN est rattachée au département Sciences des Données et Systèmes Communicants."
  },
  {
    "id": "fi017",
    "category": "filieres",
    "question": "Qu'est-ce que la filière Ingénierie Logicielle et Intelligence Artificielle ?",
    "answer": "Cette filière forme des ingénieurs experts en développement logiciel et en intelligence artificielle. Le programme couvre la POO Java, le développement web frontend et backend, Python et frameworks IA, les bases de données Oracle et NoSQL, le machine learning et deep learning, l'apprentissage par renforcement, le computer vision, le big data, le NLP, l'IA générative, le DevOps, la business intelligence et les tests logiciels. Elle est coordonnée par KHAMLICHI YOUNESS.",
    "context": "La filière ILIA est rattachée au département Génie des Systèmes Intelligents."
  },
  {
    "id": "fi018",
    "category": "filieres",
    "question": "Qu'est-ce que le Cycle Préparatoire de l'ENSA Fès ?",
    "answer": "Le Cycle Préparatoire Intégré de l'ENSA Fès dure 2 ans (4 semestres) et constitue le socle scientifique commun à toutes les filières. Il couvre les mathématiques (algèbre, analyse, probabilités), la physique (mécanique, thermodynamique, électromagnétisme, optique), l'informatique (programmation C, C++, numérique), les langues (anglais et français), et des matières transversales comme la culture entrepreneuriale. Il prépare les étudiants aux concours d'accès au cycle ingénieur.",
    "context": "Le cycle préparatoire de l'ENSA Fès est intégré à l'école, contrairement aux CPGE externes."
  },
  {
    "id": "fi019",
    "category": "filieres",
    "question": "Quels modules sont enseignés en Cycle Préparatoire à l'ENSA Fès ?",
    "answer": "Le Cycle Préparatoire comprend 4 semestres. En 1ère année : Algèbre 1 et 2, Analyse 1 et 2, Mécanique du point, Introduction à l'électronique (analogique et numérique), Informatique 1, Anglais/Français, Thermodynamique, Électrostatique et Magnétostatique, Chimie générale, Dessin industriel, Programmation C, et Digital skills. En 2ème année : Analyse 3 et 4, Algèbre 3, Analyse numérique, Programmation C avancée, Mécanique du solide, Mécanique des fluides, Électrocinétique, Statistiques et probabilités, Optique, Électromagnétisme et physique des ondes, et Culture entrepreneuriale.",
    "context": "Le cycle préparatoire pose les bases mathématiques, physiques et informatiques nécessaires au cycle ingénieur."
  },
  {
    "id": "fi020",
    "category": "filieres",
    "question": "L'ENSA Fès propose-t-elle des formations continues ?",
    "answer": "Oui, l'ENSA Fès propose des formations continues sous forme de Licences et Masters d'université. Parmi les licences : CRSI, FDWJEE, IAWM, IL, M2I. Parmi les masters : 2ISD, CMPI, DLA, GLD, GLSI, IANT, IDIA, M2I, SICN. Ces formations permettent aux professionnels en activité de se spécialiser ou d'acquérir de nouvelles compétences.",
    "context": "La formation continue de l'ENSA Fès s'adresse à des publics en reconversion ou souhaitant approfondir leurs compétences."
  },

  {
    "id": "dep001",
    "category": "departements",
    "question": "Qui dirige le département Génie Industriel à l'ENSA Fès ?",
    "answer": "Le département Génie Industriel est dirigé par HIHI HICHAM (hicham.hihi@usmba.ac.ma). Il supervise les filières Génie Énergétique et Systèmes Intelligents (coordonnée par HIHI HICHAM), Génie Industriel (coordonnée par EL KHATTABI SOUAD - souad.elkhattabi@usmba.ac.ma), Génie Mécanique (coordonnée par EL HAINI JAMILA - jamila.elhaini@usmba.ac.ma), et Génie Mécatronique (coordonnée par SAYYOURI MHAMED - mhamed.sayyouri@usmba.ac.ma).",
    "context": "Le département Génie Industriel de l'ENSA Fès regroupe les filières liées aux systèmes mécaniques, énergétiques et de production."
  },
  {
    "id": "dep002",
    "category": "departements",
    "question": "Quels sont les enseignants du département Génie Industriel à l'ENSA Fès ?",
    "answer": "Le département Génie Industriel regroupe les enseignants suivants : AZRAR Abdellhadi (abdellhadi.azrar@usmba.ac.ma), CHAIBI Yassine (chaibi.yassine@usmba.ac.ma), CHALH Zakaria (zakaria.chalh@usmba.ac.ma), EL KHATTABI Souad (souad.elkhattabi@usmba.ac.ma), EL AFOU Youssef (youssef.elafou@usmba.ac.ma), EL HAINI Jamila (jamila.elhaini@usmba.ac.ma), EL HAMMAMI Youness (youness.elhammami@usmba.ac.ma), EL HASSANI Hind (hind.elhassani@usmba.ac.ma), FARHANE Youness (youness.farhane@usmba.ac.ma), FEKAK Fatima-Ezzahra (fatima-ezzahra.fekak@usmba.ac.ma), HIHI Hicham (hicham.hihi@usmba.ac.ma), KHAISSIDI Ghizlane (ghizlane.khaissidi@usmba.ac.ma), LAAOUINA Loubna (loubna.laaouina@usmba.ac.ma), LAHRECH Khadija (Khadija.lahrech@usmba.ac.ma), MONTASSIR Soufiane (soufiane.montassir@usmba.ac.ma), MOTAHHIR Saad (saad.motahhir@usmba.ac.ma), MOUSTABCHIR Hassane (hassane.moustabchir@usmba.ac.ma), OUAHI Mohamed (mohamed.ouahi@usmba.ac.ma), OUHAIBI Salma (salma.ouhaibi@usmba.ac.ma), SAKA Abdelmjid (abdelmjid.saka@usmba.ac.ma), SALHI Mohamed (mohamed.salhi@usmba.ac.ma), SAYYOURI Mhamed (mhamed.sayyouri@usmba.ac.ma), TAHIRI Mohamed Amine (mohamedamine.tahiri@usmba.ac.ma).",
    "context": "Le département Génie Industriel dispose d'une équipe enseignante diversifiée couvrant mécanique, énergie, automatique et industrie."
  },
  {
    "id": "dep003",
    "category": "departements",
    "question": "Qui dirige le département Génie Électrique et Informatique à l'ENSA Fès ?",
    "answer": "Le département Génie Électrique et Informatique est dirigé par EZZOUHAIRI ABDELLATIF (abdellatif.ezzouhairi@polymtl.ca). Il supervise les filières Génie du Développement Numérique et Cybersécurité (coordonnée par JEGHAL ADIL - adil.jeghal@usmba.ac.ma), Génie Informatique (coordonnée par BOULAALAM ABDELHAK - ginfo.ensa@usmba.ac.ma / +212678715327), et Ingénierie en Science de Données et Intelligence Artificielle (coordonnée par EL AKKAD NABIL - nabil.elakkad@usmba.ac.ma).",
    "context": "Le département GEI de l'ENSA Fès est l'un des plus importants de l'école, couvrant l'informatique et les systèmes électriques."
  },
  {
    "id": "dep004",
    "category": "departements",
    "question": "Quels sont les enseignants du département Génie Électrique et Informatique à l'ENSA Fès ?",
    "answer": "Le département Génie Électrique et Informatique regroupe : BERRADA Mohammed (mohammed.berrada@gmail.com), BERNOUSSI Benaissa (bbernou@gmail.com), BALBOUL Younes (younes.balboul@usmba.ac.ma), BOULAALAM Abdelhak (abdelhak.boulaalam@usmba.ac.ma), CHAOUI Nour El Houda (houda.chaoui@usmba.ac.ma), EL AKKAD Nabil (nabil.elakkad@usmba.ac.ma), ELHAJ BENALI Safae (anasafae@gmail.com), EZZOUHAIRI Abdellatif (abdellatif.ezzouhairi@polymtl.ca), MAZIR Said (mazersaid@gmail.com), JEGHAL Adil (adil.jeghal@usmba.ac.ma), KENZI Adil (adil.kenzi@gmail.com), OUDGHIRI BENTAIE Mohammed (oudghiri.m@gmail.com), YAKINE Fadoua (fadoua.yakine@usmba.ac.ma).",
    "context": "Le département GEI dispose d'une équipe enseignante spécialisée en informatique, réseaux, bases de données et intelligence artificielle."
  },
  {
    "id": "dep005",
    "category": "departements",
    "question": "Qui dirige le département Génie des Systèmes Intelligents à l'ENSA Fès ?",
    "answer": "Le département Génie des Systèmes Intelligents est dirigé par LAKHRISSI Younes (younes.lakhrissi@usmba.ac.ma). Il supervise les filières Ingénierie Logicielle et Intelligence Artificielle (coordonnée par KHAMLICHI YOUNESS - youness.khamlichi@usmba.ac.ma) et Ingénierie des Systèmes Embarqués et Intelligence Artificielle (coordonnée par ALAMI MARKTANI MALIKA - malika.alamimarktani@usmba.ac.ma).",
    "context": "Le département GSI est spécialisé dans l'intelligence artificielle et les systèmes embarqués."
  },
  {
    "id": "dep006",
    "category": "departements",
    "question": "Quels sont les enseignants du département Génie des Systèmes Intelligents à l'ENSA Fès ?",
    "answer": "Le département Génie des Systèmes Intelligents regroupe : ALAMI MARKTANI Malika (malika.alamimarktani@usmba.ac.ma), BELKEBIR Hicham (hicham.belkebir@usmba.ac.ma), BELLAMINE Insaf (Insaf.bellamine@usmba.ac.ma), BENNANI DOSSE Saâd (saad.bennanidosse@usmba.ac.ma), CHAFI Saad (saad.chafi@usmba.ac.ma), CHOUGRAD Hiba (hiba.chougrad@usmba.ac.ma), ELBDOURI Abdelali (abdelali.elbdouri@usmba.ac.ma), IDRISSI KHAMLICHI YOUNESS (youness.khamlichi@usmba.ac.ma), LAKHRISSI Younes (younes.lakhrissi@usmba.ac.ma), MAILKA Hamza (haamza.mailka@gmail.com), MANSOURI Anass (anass.mansouri@usmba.ac.ma), RASSIL Asmaa (asmaa.rassil@usmba.ac.ma), TOUZANI Hajar (hajar.touzani@usmba.ac.ma).",
    "context": "Le département GSI dispose d'une équipe enseignante spécialisée en IA, systèmes embarqués et logiciel."
  },
  {
    "id": "dep007",
    "category": "departements",
    "question": "Quels sont les enseignants du département Mathématiques Appliquées à l'ENSA Fès ?",
    "answer": "Le département Mathématiques Appliquées regroupe : ABERQI Ahmed (aberqi_ahmed@yahoo.fr), BEN HADDOUCH Khalil (khalil.benhaddouch@usmba.ac.ma), BERNOUSSI Benaissa (benaissa.bernoussi@usmba.ac.ma), ELHAJ BENALI Safae (anasafae@gmail.com), JERROUD Amine, KARITE Touria (touria.karite@gmail.com), MAZGOURI Zakaria (zakaria.mazgouri@usmba.ac.ma), YOUSSFI Ahmed (ahmed.youssfi@usmba.ac.ma).",
    "context": "Le département Mathématiques Appliquées assure les enseignements en mathématiques fondamentales et appliquées pour toutes les filières."
  },
  {
    "id": "dep008",
    "category": "departements",
    "question": "Quels sont les enseignants du département Intelligence Économique, Langues et Soft-Skills à l'ENSA Fès ?",
    "answer": "Le département Intelligence Économique, Langues et Soft-Skills regroupe : ACHAHBAR Asmae (asmae.achahbar@usmba.ac.ma), ALLA Lhoussaine (lhoussaine.alla.ma@gmail.com), BOULAICH Mohammed Ali (mohammedali.boulaich1@usmba.ac.ma), DAHBI Manar (manardahbi@gmail.com), KHOUMSSI Khaoula (kh.khoumssi@gmail.com), MADANI-ALAOUI Khadija (madanialaoui.khadija@gmail.com), NASRI Sanae (sanae.nasri1@usmba.ac.ma), OUDIJA Mustapha (mustapha.oudija@usmba.ac.ma), SBAI Abdenabi (abdenabi.sbai@usmba.ac.ma).",
    "context": "Ce département assure les enseignements en langues (anglais, français), soft-skills et culture entrepreneuriale pour toutes les filières."
  },
  {
    "id": "dep009",
    "category": "departements",
    "question": "Qui dirige le département Sciences des Données et Systèmes Communicants à l'ENSA Fès ?",
    "answer": "Le département Sciences des Données et Systèmes Communicants est dirigé par CHETIOUI Kaouthar (kaouthar.chetioui@usmba.ac.ma). Il supervise les filières Génie des Systèmes Communicants et Sécurité Informatique (coordonnée par BALBOUL YOUNES - younes.balboul@usmba.ac.ma) et Ingénierie Informatique, Intelligence Artificielle et Confiance Numérique (coordonnée par BERRADA MOHAMMED - mohammed-berrada@usmba.ac.ma).",
    "context": "Ce département est spécialisé dans les réseaux de communication, la sécurité et la science des données."
  },
  {
    "id": "dep010",
    "category": "departements",
    "question": "Quels sont les enseignants du département Sciences des Données et Systèmes Communicants à l'ENSA Fès ?",
    "answer": "Le département Sciences des Données et Systèmes Communicants regroupe : BALBOUL Younes (younes.balboul@usmba.ac.ma), BERRADA Mohammed (mohammed.berrada@gmail.com / mohammed-berrada@usmba.ac.ma), CHETIOUI Kaouthar (kaouthar.chetioui@usmba.ac.ma), EL BEKKALI Moulhime (moulhime.elbekkali@usmba.ac.ma), HRAOUI Said (hraoui.said@gmail.com), MAZER Said (Mazersaid@gmail.com), MELLOULI El Mehdi (mellouli_elmehdi@hotmail.com).",
    "context": "Ce département dispose d'une équipe enseignante spécialisée en réseaux, sécurité et traitement des données."
  },

  {
    "id": "ad001",
    "category": "admissions",
    "question": "Comment intégrer l'ENSA Fès ?",
    "answer": "L'admission à l'ENSA Fès se fait principalement via le Concours National Commun (CNC) pour les bacheliers scientifiques ou les étudiants ayant validé une classe préparatoire (CPGE). L'accès au Cycle Préparatoire Intégré est réservé aux bacheliers ayant obtenu une mention Bien ou Très Bien en Sciences Mathématiques ou Sciences Physiques. Une admission sur titre (parallèle) est également possible pour les titulaires de DUT, BTS ou Licence.",
    "context": "L'ENSA Fès suit le processus national d'admission aux écoles nationales des sciences appliquées."
  },
  {
    "id": "ad002",
    "category": "admissions",
    "question": "Quel bac faut-il avoir pour rentrer à l'ENSA Fès ?",
    "answer": "Il faut être titulaire d'un baccalauréat scientifique marocain, de préférence en Sciences Mathématiques A ou B, ou en Sciences Physiques, avec une mention Bien ou Très Bien. Les candidats issus d'autres séries scientifiques peuvent aussi postuler selon les conditions fixées chaque année par le Ministère de l'Enseignement Supérieur.",
    "context": "L'admission au cycle préparatoire de l'ENSA Fès est conditionnée par le niveau du baccalauréat obtenu."
  },

  {
    "id": "sc001",
    "category": "scolarite",
    "question": "Quels sont les frais de scolarité à l'ENSA Fès ?",
    "answer": "L'ENSA Fès est un établissement public relevant de l'Université Sidi Mohamed Ben Abdellah (USMBA). Les frais d'inscription sont très réduits, de l'ordre de quelques centaines de dirhams par an, conformément à la politique nationale d'accès à l'enseignement supérieur public. Des bourses d'excellence et des aides sociales sont disponibles pour les étudiants méritants ou en situation de besoin.",
    "context": "En tant qu'établissement public, l'ENSA Fès rend la formation d'ingénieur accessible financièrement."
  },
  {
    "id": "sc002",
    "category": "scolarite",
    "question": "Quel est le calendrier académique de l'ENSA Fès ?",
    "answer": "L'année académique à l'ENSA Fès est divisée en deux semestres. Le premier semestre commence en septembre et les examens se tiennent en janvier. Le second semestre commence en février et les examens ont lieu en juin. Des sessions de rattrapage sont organisées après chaque session principale pour les étudiants n'ayant pas validé certains modules.",
    "context": "Le système semestriel de l'ENSA Fès suit le calendrier national de l'enseignement supérieur marocain."
  },
  {
    "id": "sc003",
    "category": "scolarite",
    "question": "Y a-t-il une résidence universitaire à l'ENSA Fès ?",
    "answer": "Oui, l'ENSA Fès dispose d'une cité universitaire pour héberger les étudiants venant d'autres villes, avec des tarifs subventionnés par l'État. Les étudiants peuvent faire une demande d'hébergement en début d'année auprès du service des affaires estudiantines. La restauration universitaire est également disponible à prix subventionné.",
    "context": "Les infrastructures d'hébergement de l'ENSA Fès facilitent la vie des étudiants venant d'autres régions du Maroc."
  },

  {
    "id": "st001",
    "category": "stages",
    "question": "Y a-t-il des stages obligatoires à l'ENSA Fès ?",
    "answer": "Oui, les stages sont obligatoires à l'ENSA Fès et font partie intégrante du cursus. Il y a un stage ouvrier en 2ème année de cycle préparatoire, un stage technicien en 1ère année du cycle ingénieur, et un Projet de Fin d'Études (PFE) de 4 à 6 mois réalisé en 3ème année du cycle ingénieur. Le PFE est effectué en entreprise ou en laboratoire de recherche et donne lieu à un rapport et une soutenance devant jury.",
    "context": "Les stages de l'ENSA Fès sont conçus pour intégrer progressivement les étudiants dans le monde professionnel."
  },
  {
    "id": "st002",
    "category": "stages",
    "question": "Quels sont les débouchés après le diplôme de l'ENSA Fès ?",
    "answer": "Les diplômés de l'ENSA Fès intègrent des secteurs variés : informatique et télécommunications, énergie et environnement, industrie et génie mécanique, banque et finance, conseil et audit, et administration publique. Beaucoup rejoignent de grandes entreprises marocaines (OCP, Maroc Telecom, ONEE, CIH, etc.) ou des multinationales. Une partie des diplômés poursuit en master ou doctorat au Maroc ou à l'étranger.",
    "context": "Le diplôme d'ingénieur d'État de l'ENSA Fès est reconnu nationalement et ouvre des portes dans de nombreux secteurs."
  },

  {
    "id": "co001",
    "category": "contacts",
    "question": "Quel est le contact de l'administration de l'ENSA Fès ?",
    "answer": "L'administration de l'ENSA Fès peut être contactée par email à contact@ensa-fes.ma ou par téléphone au +212 5 35 60 00 00. L'école est rattachée à l'Université Sidi Mohamed Ben Abdellah (USMBA) de Fès.",
    "context": "L'ENSA Fès dispose d'un service administratif accessible par différents moyens de communication."
  },
  {
    "id": "co002",
    "category": "contacts",
    "question": "Où se trouve l'ENSA Fès ?",
    "answer": "L'ENSA Fès est située sur la Route d'Imouzzer à Fès, Maroc. Le campus est facilement accessible depuis le centre-ville. Elle fait partie de l'Université Sidi Mohamed Ben Abdellah (USMBA), l'une des plus grandes universités du Maroc.",
    "context": "L'ENSA Fès est implantée dans la ville de Fès, capitale scientifique et spirituelle du Maroc."
  },
  {
    "id": "co003",
    "category": "contacts",
    "question": "Comment contacter le coordinateur de la filière Génie Informatique à l'ENSA Fès ?",
    "answer": "Le coordinateur de la filière Génie Informatique est BOULAALAM ABDELHAK. Il peut être contacté par email à ginfo.ensa@usmba.ac.ma ou par téléphone au +212 678 715 327.",
    "context": "Chaque filière de l'ENSA Fès dispose d'un coordinateur dédié pour les questions pédagogiques et administratives."
  },

  {
    "id": "cl001",
    "category": "clubs",
    "question": "Quels sont les clubs disponibles à l'ENSA Fès ?",
    "answer": "L'ENSA Fès dispose de nombreux clubs étudiants couvrant des domaines techniques, culturels et sportifs : Club Informatique, Club Robotique, Club Électronique, Club Sportif, Club Culturel, Club Développement Durable et Club Entrepreneuriat. Ces clubs organisent des événements, des ateliers, des compétitions et des conférences tout au long de l'année académique.",
    "context": "La vie associative à l'ENSA Fès est riche et permet aux étudiants de développer leurs compétences en dehors des cours."
  },
  {
    "id": "cl002",
    "category": "clubs",
    "question": "Comment rejoindre un club à l'ENSA Fès ?",
    "answer": "Pour rejoindre un club à l'ENSA Fès, il suffit de contacter le bureau du club concerné en début d'année, notamment lors de la Journée des Clubs organisée au début de chaque année académique. Les clubs sont ouverts à tous les étudiants de l'école, quelle que soit leur filière ou leur année d'études. Le service des affaires estudiantines peut fournir des informations supplémentaires sur les clubs actifs.",
    "context": "Les clubs de l'ENSA Fès recrutent leurs membres principalement en début d'année académique."
  }
]

print(f"Base de connaissances : {len(ensa_data)} entrées")
print("Catégories :", set(d["category"] for d in ensa_data))

print(f"Base de connaissances : {len(ensa_data)} entrées")
print("Catégories :", set(d["category"] for d in ensa_data))
# Out:
# Base de connaissances : 42 entrées
# Catégories : {'departements', 'stages', 'contacts', 'clubs', 'admissions', 'filieres', 'scolarite'}
# Base de connaissances : 42 entrées
# Catégories : {'departements', 'stages', 'contacts', 'clubs', 'admissions', 'filieres', 'scolarite'}

# %%
with open("ensa_kb.json", "w", encoding="utf-8") as f:
    json.dump(ensa_data, f, ensure_ascii=False, indent=2)

print("ensa_kb.json sauvegardé avec succès !")
# Out:
# ensa_kb.json sauvegardé avec succès !
